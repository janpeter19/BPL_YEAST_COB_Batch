# %% [markdown]
# <a href="https://colab.research.google.com/github/janpeter19/BPL_YEAST_COB_Batch/blob/main/BPL_YEAST_COB_Batch_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BPL_YEAST_COB_Batch script with PyFMI
#
# The key library PyFMI is installed.
#
# After the installation a small application BPL_YEAST_COB_Batch is loaded and run. You can continue with this example if you like.

# %%
# !lsb_release -a # Actual VM Ubuntu version used by Google
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.5 LTS
# Release:	22.04
# Codename:	jammy

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# !python --version
# Out:
# Python 3.13.15

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py313_26.5.3-2-Linux-x86_64.sh
# !chmod +x Miniconda3-py313_26.5.3-2-Linux-x86_64.sh
# !bash ./Miniconda3-py313_26.5.3-2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.13/site-packages/')
# Out:
# --2026-08-29 11:32:48--  https://repo.anaconda.com/miniconda/Miniconda3-py313_26.5.3-2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 193340122 (184M) [application/octet-stream]
# Saving to: ‘Miniconda3-py313_26.5.3-2-Linux-x86_64.sh’
#
# Miniconda3-py313_26 100%[===================>] 184.38M   273MB/s    in 0.7s
#
# 2026-08-29 11:32:49 (273 MB/s) - ‘Miniconda3-py313_26.5.3-2-Linux-x86_64.sh’ saved [193340122/193340122]
#
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.

# %%
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# !conda update -n base -c defaults conda --yes
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.8.13  |       h06a4308_0         107 KB
#     certifi-2026.7.22          |  py313h06a4308_0         135 KB
#     conda-26.7.1               |  py313h06a4308_0         1.3 MB
#     ------------------------------------------------------------
#                                            Total:         1.5 MB
#
# The following packages will be REMOVED:
#
#   jsonpatch-1.33-py313h06a4308_1
#   jsonpointer-3.1.1-py313h06a4308_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2026.7.16-h06a4308_0 --> 2026.8.13-h06a4308_0
#   certifi                         2026.6.17-py313h06a4308_0 --> 2026.7.22-py313h06a4308_0
#   conda                              26.5.3-py313h06a4308_0 --> 26.7.1-py313h06a4308_0
#
#
#
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Channel "defaults" has the following notices:
#   [info] -- Thu Aug  6 00:00:00 2026
#   main-x (Anaconda's new authenticated channel) is now generally available, with thousands of additional packages from our secure supply chain. Get started at: https://anaconda.com/docs/getting-started/main-x?utm_source=channel_notices

# %%
# !conda --version
# !python --version
# Out:
# conda 26.7.1
# Python 3.13.14

# %%
# !conda config --set channel_priority strict

# %%
# !conda install -c conda-forge pyfmi --yes # Install the key package
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pyfmi
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _x86_64-microarch-level-3  |      3_broadwell          10 KB  conda-forge
#     assimulo-3.8.0             |np2py313h7dd1d38_1         1.1 MB  conda-forge
#     fmilib-3.0.4               |       h394bbc8_2         407 KB  conda-forge
#     gmp-6.3.0                  |       hfd2156b_3         482 KB  conda-forge
#     libamd-3.3.3               | haaf9dc3_7100102          49 KB  conda-forge
#     libblas-3.11.0             |9_h4a7cf45_openblas          18 KB  conda-forge
#     libbtf-2.3.2               | h32481e8_7100102          27 KB  conda-forge
#     libcamd-3.3.3              | h32481e8_7100102          46 KB  conda-forge
#     libcblas-3.11.0            |9_h0358290_openblas          18 KB  conda-forge
#     libccolamd-3.3.4           | h32481e8_7100102          42 KB  conda-forge
#     libcholmod-5.3.1           | h59ddab4_7100102         1.1 MB  conda-forge
#     libcolamd-3.3.4            | h32481e8_7100102          33 KB  conda-forge
#     libcxsparse-4.4.1          | h32481e8_7100102         118 KB  conda-forge
#     libgfortran-15.2.0         |      h69a702a_20          27 KB  conda-forge
#     libgfortran5-15.2.0        |      h68bc16d_20         2.4 MB  conda-forge
#     libklu-2.3.5               | hf24d653_7100102         142 KB  conda-forge
#     liblapack-3.11.0           |9_h47877c9_openblas          18 KB  conda-forge
#     libldl-3.3.2               | h32481e8_7100102          24 KB  conda-forge
#     liblzma-5.8.2              |       hb03c661_0         111 KB  conda-forge
#     libopenblas-0.3.34         |pthreads_h94d23a6_0         5.7 MB  conda-forge
#     libparu-1.0.0              | h17147ab_7100102          91 KB  conda-forge
#     librbio-4.3.4              | h32481e8_7100102          47 KB  conda-forge
#     libspex-3.2.3              | had10066_7100102          79 KB  conda-forge
#     libspqr-4.3.4              | h852d39f_7100102         213 KB  conda-forge
#     libsuitesparseconfig-7.10.1| h92d6892_7100102          42 KB  conda-forge
#     libumfpack-6.3.5           | heb53515_7100102         424 KB  conda-forge
#     metis-5.1.0                |    hd0bcaf9_1007         3.7 MB  conda-forge
#     minizip-4.0.10             |       h05a5f5f_0          91 KB  conda-forge
#     mpfr-4.2.2                 |       ha2cb11d_1         713 KB  conda-forge
#     numpy-2.5.2                |  py313hf6604e3_0         8.6 MB  conda-forge
#     openssl-3.6.4              |       h781a0a9_0         3.1 MB  conda-forge
#     pyfmi-2.22.0               |np2py313hfeff522_0         5.7 MB  conda-forge
#     scipy-1.18.0               |  py313h4b8bb8b_0        16.4 MB  conda-forge
#     suitesparse-7.10.1         | ha0f6916_7100102          12 KB  conda-forge
#     sundials-7.8.0             |       h8a7dba9_0         1.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        52.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _x86_64-microarch~ conda-forge/noarch::_x86_64-microarch-level-3-3_broadwell
#   assimulo           conda-forge/linux-64::assimulo-3.8.0-np2py313h7dd1d38_1
#   fmilib             conda-forge/linux-64::fmilib-3.0.4-h394bbc8_2
#   gmp                conda-forge/linux-64::gmp-6.3.0-hfd2156b_3
#   libamd             conda-forge/linux-64::libamd-3.3.3-haaf9dc3_7100102
#   libblas            conda-forge/linux-64::libblas-3.11.0-9_h4a7cf45_openblas
#   libbtf             conda-forge/linux-64::libbtf-2.3.2-h32481e8_7100102
#   libcamd            conda-forge/linux-64::libcamd-3.3.3-h32481e8_7100102
#   libcblas           conda-forge/linux-64::libcblas-3.11.0-9_h0358290_openblas
#   libccolamd         conda-forge/linux-64::libccolamd-3.3.4-h32481e8_7100102
#   libcholmod         conda-forge/linux-64::libcholmod-5.3.1-h59ddab4_7100102
#   libcolamd          conda-forge/linux-64::libcolamd-3.3.4-h32481e8_7100102
#   libcxsparse        conda-forge/linux-64::libcxsparse-4.4.1-h32481e8_7100102
#   libgfortran        conda-forge/linux-64::libgfortran-15.2.0-h69a702a_20
#   libgfortran5       conda-forge/linux-64::libgfortran5-15.2.0-h68bc16d_20
#   libklu             conda-forge/linux-64::libklu-2.3.5-hf24d653_7100102
#   liblapack          conda-forge/linux-64::liblapack-3.11.0-9_h47877c9_openblas
#   libldl             conda-forge/linux-64::libldl-3.3.2-h32481e8_7100102
#   liblzma            conda-forge/linux-64::liblzma-5.8.2-hb03c661_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.34-pthreads_h94d23a6_0
#   libparu            conda-forge/linux-64::libparu-1.0.0-h17147ab_7100102
#   librbio            conda-forge/linux-64::librbio-4.3.4-h32481e8_7100102
#   libspex            conda-forge/linux-64::libspex-3.2.3-had10066_7100102
#   libspqr            conda-forge/linux-64::libspqr-4.3.4-h852d39f_7100102
#   libsuitesparsecon~ conda-forge/linux-64::libsuitesparseconfig-7.10.1-h92d6892_7100102
#   libumfpack         conda-forge/linux-64::libumfpack-6.3.5-heb53515_7100102
#   metis              conda-forge/linux-64::metis-5.1.0-hd0bcaf9_1007
#   minizip            conda-forge/linux-64::minizip-4.0.10-h05a5f5f_0
#   mpfr               conda-forge/linux-64::mpfr-4.2.2-ha2cb11d_1
#   numpy              conda-forge/linux-64::numpy-2.5.2-py313hf6604e3_0
#   pyfmi              conda-forge/linux-64::pyfmi-2.22.0-np2py313hfeff522_0
#   scipy              conda-forge/linux-64::scipy-1.18.0-py313h4b8bb8b_0
#   suitesparse        conda-forge/linux-64::suitesparse-7.10.1-ha0f6916_7100102
#   sundials           conda-forge/linux-64::sundials-7.8.0-h8a7dba9_0
#
# The following packages will be UPDATED:
#
#   openssl               pkgs/main::openssl-3.5.7-h1b28b03_0 --> conda-forge::openssl-3.6.4-h781a0a9_0
#
#
#
# Downloading and Extracting Packages:
#
# done
# done
# done

# %%
# !pip install optlang
# Out:
# Collecting optlang
#   Downloading optlang-1.9.1-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting swiglpk>=5.0.12 (from optlang)
#   Downloading swiglpk-5.0.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.7 kB)
# Collecting sympy>=1.12.0 (from optlang)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.12.0->optlang)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading optlang-1.9.1-py2.py3-none-any.whl (141 kB)
# Downloading swiglpk-5.0.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 47.4 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 119.7 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 14.2 MB/s  0:00:00
# Installing collected packages: swiglpk, mpmath, sympy, optlang
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [optlang]
# Successfully installed mpmath-1.3.0 optlang-1.9.1 swiglpk-5.0.13 sympy-1.14.0

# %%
# !pip install git+https://github.com/janpeter19/FMU_explore.git
# Out:
# Collecting git+https://github.com/janpeter19/FMU_explore.git
#   Cloning https://github.com/janpeter19/FMU_explore.git to /tmp/pip-req-build-qyq_eq21
#   Running command git clone --filter=blob:none --quiet https://github.com/janpeter19/FMU_explore.git /tmp/pip-req-build-qyq_eq21
#   Resolved https://github.com/janpeter19/FMU_explore.git to commit 661e7d172db6ec0f1798410c3a2bf41b46370eac
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: fmu_explore_pyfmi
#   Building wheel for fmu_explore_pyfmi (pyproject.toml) ... done
#   Created wheel for fmu_explore_pyfmi: filename=fmu_explore_pyfmi-1.1.2-py3-none-any.whl size=18807 sha256=936b45374501fecb3c348c7db058059f0b46704f11dbed56b6c38fa1374b5d5a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t6jzpuqn/wheels/98/33/d9/8669158b0d845b084c49212b2330ad684e92d7a9ac84fcea8d
# Successfully built fmu_explore_pyfmi
# Installing collected packages: fmu_explore_pyfmi
# Successfully installed fmu_explore_pyfmi-1.1.2

# %% [markdown]
# # Notes YEAST_COB_Batch constraint-based approach

# %% [markdown]
# Now specific installation and the run simulations. Start with connecting to Github. Then upload the two files:
#
# * FMU - BPL_YEAST_AIR_Fedbatch_linux_jm_cs.fmu
# * Setup-file - BPL_YEAST_AIR_Fedbatch_explore

# %%
# %%bash
# git clone https://github.com/janpeter19/BPL_YEAST_COB_Batch
# Out:
# Cloning into 'BPL_YEAST_COB_Batch'...

# %%
# %cd BPL_YEAST_COB_Batch
# Out:
# /content/BPL_YEAST_COB_Batch

# %%
# Import the application model and context variables
from BPL_YEAST_COB_Batch import*
# Out:
# Linux - run FMU pre-compiled OpenModelica

# %%
# Impprt the general FMU_explore functions ana adapt them to the application
from fmu_explore_pyfmi import fmu_explore
Dummy = fmu_explore(model, parValue, parLocation, parCheck,\
                    fmu_model, fmu_process_diagram,\
                    MSL_usage, MSL_version, BPL_version,\
                    opts_fast, simulationTime, timeDiscreteStates, stateValue,\
                    diagrams, ax, lines)
par = Dummy.par
init = Dummy.init
disp = Dummy.disp
simu = Dummy.simu
show = Dummy.show
setPen = Dummy.setPen
resetPen = Dummy.resetPen
process_diagram = Dummy.process_diagram
describe_general = Dummy.describe_general
describe_parts = Dummy.describe_parts
describe_MSL = Dummy.describe_MSL
FMU_explore_info = Dummy.FMU_explore_info
system_info = Dummy.system_info
SDG = Dummy.SDG

# %%
run -i BPL_YEAST_COB_Batch_explore.py
# Out:
# Model for the process has been setup. Key commands:
#  - par()       - change of parameters and initial values
#  - init()      - change initial values only
#  - simu()      - simulate and plot
#  - newplot()   - make a new plot
#  - show()      - show plot from previous simulation
#  - disp()      - display parameters and initial values from the last simulation
#  - describe()  - describe culture, broth, parameters, variables with values/units
#
# Note that both disp() and describe() takes values from the last simulation
# and the command process_diagram() brings up the main configuration
#
# Brief information about a command by help(), eg help(simu)
# Key system information is listed with the command system_info()

# %%
plt.rcParams['figure.figsize'] = [20/2.54, 16/2.54]

# %%
describe('process')
# Out:
# Batch cultivation of yeast

# %%
process_diagram()
# Out:
# No processDiagram.png file in the FMU, but try the file on disk.

# %% [markdown]
# ## Try using LP in each step

# %%
from optlang import Model, Variable, Constraint, Objective

# %%
# Define culture constraint-based model
def culture(G, E):

    # LP calculation of the optimal qGr, qEr based on G and E values

    # - parameters
    qO2max = 6.9e-3; kog = 2.3; koe = 1.6; YGr = 3.5; YEr = 1.32;
    alpha = 0.01; beta = 1.0

    # - transfer data from dynamic reactor model to static LP model
    qGr_opt = Variable('qGr_opt', lb=0)
    qEr_opt = Variable('qEr_opt', lb=0)

    # - LP model constraint and objective
    mu_max = Objective(YGr*qGr_opt + YEr*qEr_opt, direction='max')
    qO2lim = Constraint(kog*qGr_opt + koe*qEr_opt, ub=qO2max)
    qGlim = Constraint(qGr_opt, ub=alpha*max(0,G))
    qElim = Constraint(qEr_opt, ub=beta*max(0,E))

    # - put together the LP model
    yeast_model = Model(name='Yeast bottleneck model')
    yeast_model.objective = mu_max
    yeast_model.add(qO2lim)
    yeast_model.add(qGlim)
    yeast_model.add(qElim)

    # - do LP optimization
    yeast_model.optimize()

    return (yeast_model.objective.value, yeast_model.variables.qGr_opt.primal, yeast_model.variables.qEr_opt.primal, qO2lim.primal)

# %%
# Initialization
V_start=1.0
init(V_start=V_start, VX_start=V_start*2.0, VG_start=V_start*10, VE_start=V_start*3.0)

# %%
# Loop of simulations
t_final = 8.0
t_samp = 0.0333
n_samp = t_final/t_samp + 1

# %%
# Simulate n sample steps
newplot(title='Batch cultivation', plotType='TimeSeries2')
ax[0].set_xlim([0, t_final]); ax[1].set_xlim([0, t_final]); ax[2].set_xlim([0, t_final])

sim_res = simu(t_samp)
for i in range(int(n_samp)):
    (mum_opt, qGr_opt, qEr_opt, qO2_opt) = culture(sim_res['bioreactor.c[2]'][-1], sim_res['bioreactor.c[3]'][-1])
    par(mum=mum_opt, qGr=qGr_opt, qEr=qEr_opt, qO2=qO2_opt)
    sim_res = simu(t_samp, 'cont')
# Out:
# Could not find cannot import name 'dopri5' from 'assimulo.lib' (/usr/local/lib/python3.13/site-packages/assimulo/lib/__init__.py)
# Could not find cannot import name 'rodas' from 'assimulo.lib' (/usr/local/lib/python3.13/site-packages/assimulo/lib/__init__.py)
# Could not find cannot import name 'odassl' from 'assimulo.lib' (/usr/local/lib/python3.13/site-packages/assimulo/lib/__init__.py)
# Could not find ODEPACK functions.
# Could not find RADAR5
# Could not find GLIMDA.

# %%
describe('MSL')
# Out:
# MSL: 4.1.0 - used components: none

# %%
system_info()
# Out:
# System information
#  -OS: Linux
#  -Python: 3.13.15
#  -Scipy: not installed in the notebook
#  -PyFMI: 2.22.0
#  -FMU by: OpenModelica Compiler OpenModelica 1.26.3~1-g7583224
#  -FMI: 2.0
#  -Type: FMUModelME2
#  -Name: BPL_YEAST_COB.Batch
#  -Generated: 2026-04-11T16:55:49Z
#  -MSL: 4.1.0
#  -Description: Bioprocess Library version 2.3.2
#  -Interaction: FMU-explore version 1.1.2

# %%
# !conda list optlang
# Out:
# # packages in environment at /usr/local:
# #
# # Name                     Version          Build            Channel
# optlang                    1.9.1            pypi_0           pypi

# %%
SDG()
